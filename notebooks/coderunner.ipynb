# %%
# !sudo apt-get install zip unzip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   unzip zip
# 0 upgraded, 2 newly installed, 0 to remove and 43 not upgraded.
# Need to get 335 kB of archives.
# After this operation, 1205 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 unzip amd64 6.0-21ubuntu1.2 [168 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 zip amd64 3.0-11build1 [167 kB]
# Fetched 335 kB in 1s (362 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
# Selecting previously unselected package unzip.
# (Reading database ... 18205 files and directories currently installed.)
# Preparing to unpack .../unzip_6.0-21ubuntu1.2_amd64.deb ...
# Unpacking unzip (6.0-21ubuntu1.2) ...
# Selecting previously unselected package zip.
# Preparing to unpack .../zip_3.0-11build1_amd64.deb ...
# Unpacking zip (3.0-11build1) ...
# ...

# %%
# !nvidia-smi
# !nvidia-smi -q -d POWER
# Out:
# Tue Apr 25 07:06:30 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.60.11    Driver Version: 525.60.11    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  On   | 00000000:43:00.0 Off |                  N/A |
# | 30%   39C    P8    20W / 350W |      1MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !unzip -q final.zip

# %%
# !conda install -y transformers
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.

# %%
import os
os.chdir('/workspace/final')
os.getcwd()
# Out:
# '/workspace/final'

# %%
# !make setup
# Out:
# cd dcase2023_task7
# conda env update -f environment.yaml --prune
# source $(conda info --base)/etc/profile.d/conda.sh ; conda activate ; conda activate dcase_task7
# wget -nc lab.sbetko.com:9001/DCASEFoleySoundSynthesisDevSet.zip
# unzip -n DCASEFoleySoundSynthesisDevSet.zip
# mkdir -p checkpoint/vqvae
# mkdir -p checkpoint/pixelsnail-final
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.3.1
#
#
#
# ...
# libcufile-1.5.1.14   | 763 KB    |                                       |   0%
# psutil-5.9.5         | 349 KB    |                                       |   0%
#
# libcublas-dev-11.9.2 | 310.9 MB  |                                       |   0%
#
#
# ...

# %%
# !export WANDB_API_KEY="<wandb_key_here>"
# !export WANDB_VQVAE_RUN_NAME="vqvae_cembed"
# !export WANDB_PROJECT="foley-final_dcase2023_task7"

# %%
# !make train_vqvae
# Out:
# cd dcase2023_task7
# conda env update -f environment.yaml --prune
# source $(conda info --base)/etc/profile.d/conda.sh ; conda activate ; conda activate dcase_task7
# wget -nc lab.sbetko.com:9001/DCASEFoleySoundSynthesisDevSet.zip
# unzip -n DCASEFoleySoundSynthesisDevSet.zip
# mkdir -p checkpoint/vqvae
# mkdir -p checkpoint/pixelsnail-final
# ...
# Solving environment: done
# #
# # To activate this environment, use
# #
# #     $ conda activate dcase_task7
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# File ‘DCASEFoleySoundSynthesisDevSet.zip’ already there; not retrieving.
#
# Archive:  DCASEFoleySoundSynthesisDevSet.zip
# export NCCL_P2P_DISABLE=1
# cd dcase2023_task7
# source $(conda info --base)/etc/profile.d/conda.sh ; conda activate ; conda activate dcase_task7
# python train_vqvae.py \
# 	--epoch 800 \
# 	--batch 512 \
# 	--sched 'ca'  \
# 	 \
#
# Traceback (most recent call last):
#   File "train_vqvae.py", line 10, in <module>
# ...

# %%
import sys
for p in sys.path:
    print(p)
# Out:
# /workspace
# /opt/conda/lib/python310.zip
# /opt/conda/lib/python3.10
# /opt/conda/lib/python3.10/lib-dynload
#
# /opt/conda/lib/python3.10/site-packages
# /opt/conda/lib/python3.10/site-packages/mpmath-1.2.1-py3.10.egg
